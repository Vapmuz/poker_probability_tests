# %% [markdown]
# In this file I'm going to use my previously made code to simulate a poker play

# %%
import card_deck as cd
import cards as card

# %%
simple_deck = cd.Deck(1)
simple_deck.shuffle()
for cards in simple_deck.cards: 
    print(cards.rank)
# Out:
# 2
# 7
# Ace
# 2
# Ace
# King
# 5
# King
# 10
# 8
# 2
# 4
# 9
# Queen
# Queen
# 9
# 3
# Queen
# 6
# 7
# 10
# 4
# King
# 8
# 6
# Jack
# 8
# 7
# 3
# Jack
# 10
# Jack
# King
# 9
# 5
# 4
# 5
# 3
# 7
# Jack
# 6
# 5
# 4
# 6
# 9
# Ace
# 8
# 2
# 3
# 10
# Queen
# Ace

# %%
simple_deck = cd.Deck(1)
for x in(("6","Diamonds"),("4","Hearts")):
    simple_deck.remove_card(x[0], x[1])
for cards in simple_deck.cards: 
    print(cards.display())
# Out:
# 2 of Hearts
# 3 of Hearts
# 5 of Hearts
# 6 of Hearts
# 7 of Hearts
# 8 of Hearts
# 9 of Hearts
# 10 of Hearts
# Jack of Hearts
# Queen of Hearts
# King of Hearts
# Ace of Hearts
# 2 of Diamonds
# 3 of Diamonds
# 4 of Diamonds
# 5 of Diamonds
# 7 of Diamonds
# 8 of Diamonds
# 9 of Diamonds
# 10 of Diamonds
# Jack of Diamonds
# Queen of Diamonds
# King of Diamonds
# Ace of Diamonds
# 2 of Clubs
# 3 of Clubs
# 4 of Clubs
# 5 of Clubs
# 6 of Clubs
# 7 of Clubs
# 8 of Clubs
# 9 of Clubs
# 10 of Clubs
# Jack of Clubs
# Queen of Clubs
# King of Clubs
# Ace of Clubs
# 2 of Spades
# 3 of Spades
# 4 of Spades
# 5 of Spades
# 6 of Spades
# 7 of Spades
# 8 of Spades
# 9 of Spades
# 10 of Spades
# Jack of Spades
# Queen of Spades
# King of Spades
# Ace of Spades

# %% [markdown]
# PROBABILITY OF HAVING A COUPLE WITH TWO DIFFERENT VALUES IN THE HAND MADE WITH X DECKS:

# %%
def check_couple(): #nrdeck,
    """I'm checking if the numbers 3 and 2 are in the next 5 cards, if  one condition is True then it returns 1"""
    my_deck = cd.Deck(2)
    hand = ("3","2")

    my_deck.shuffle()
    for x in range(5):
        my_deck.deal_card()

    for cards in my_deck.pool:
        for x in hand:
            if cards.rank == x:
                return 1
    return(0)

# %%
good_tries = 0
tries = 0
for x in range(10000):
    good_tries = good_tries + check_if_in()
    tries = tries + 1
print(good_tries/tries)
# Out:
# 0.5702
